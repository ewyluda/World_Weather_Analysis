# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Import Dependencies datetime module from datetime library
from datetime import datetime

# Create an empty list to hold the weather data

city_data = []

# print the beginning of the logging.
print('Beginning Data Retrieval     ')
print('-----------------------------')

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=04adbef39455200ca16d18e7aeb02de8

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descrip = city_weather["weather"][0]['description']
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_descrip})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | lagoa
# Processing Record 2 of Set 1 | wageningen
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | dennis
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | jadu
# Processing Record 7 of Set 1 | saint anthony
# Processing Record 8 of Set 1 | kutum
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | san lorenzo
# Processing Record 13 of Set 1 | margate
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | ambikapur
# Processing Record 19 of Set 1 | conceicao da barra
# Processing Record 20 of Set 1 | sabha
# Processing Record 21 of Set 1 | bandarbeyla
# Processing Record 22 of Set 1 | nehe
# Processing Record 23 of Set 1 | boffa
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | yichang
# Processing Record 28 of Set 1 | thompson
# Processing Record 29 of Set 1 | vityazevo
# Processing Record 30 of Set 1 | tasiilaq
# Processing Record 31 of Set 1 | tessalit
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | poya
# Processing Record 34 of Set 1 | hasaki
# Processing Record 35 of Set 1 | bosaso
# Processing Record 36 of Set 1 | lodja
# Processing Record 37 of Set 1 | kalmunai
# Processing Record 38 of Set 1 | kahului
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | copiapo
# Processing Record 41 of Set 1 | qaqortoq
# Processing Record 42 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | pevek
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | san quintin
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | skelleftea
# Processing Record 49 of Set 1 | carnarvon
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | oromocto
# Processing Record 2 of Set 2 | daru
# Processing Record 3 of Set 2 | haines junction
# Processing Record 4 of Set 2 | geraldton
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | ahipara
# Processing Record 8 of Set 2 | jalingo
# Processing Record 9 of Set 2 | belaya gora
# Processing Record 10 of Set 2 | bambanglipuro
# Processing Record 11 of Set 2 | oranjemund
# Processing Record 12 of Set 2 | tiznit
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | bafq
# Processing Record 17 of Set 2 | avarua
# Processing Record 18 of Set 2 | iqaluit
# Processing Record 19 of Set 2 | dunedin
# Processing Record 20 of Set 2 | busselton
# Processing Record 21 of Set 2 | saskylakh
# Processing Record 22 of Set 2 | rawah
# Processing Record 23 of Set 2 | catamarca
# Processing Record 24 of Set 2 | kurchum
# Processing Record 25 of Set 2 | mitu
# Processing Record 26 of Set 2 | mount gambier
# Processing Record 27 of Set 2 | te anau
# Processing Record 28 of Set 2 | upernavik
# Processing Record 29 of Set 2 | alakurtti
# Processing Record 30 of Set 2 | tetchea
# City not found. Skipping...
# Processing Record 31 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 2 | clarksburg
# Processing Record 33 of Set 2 | kerteh
# City not found. Skipping...
# Processing Record 34 of Set 2 | longyearbyen
# Processing Record 35 of Set 2 | faya
# Processing Record 36 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 2 | port elizabeth
# Processing Record 38 of Set 2 | solnechnyy
# Processing Record 39 of Set 2 | kavieng
# Processing Record 40 of Set 2 | coquimbo
# Processing Record 41 of Set 2 | mazatlan
# Processing Record 42 of Set 2 | talnakh
# Processing Record 43 of Set 2 | chokurdakh
# Processing Record 44 of Set 2 | naze
# Processing Record 45 of Set 2 | san cristobal
# Processing Record 46 of Set 2 | souillac
# Processing Record 47 of Set 2 | axim
# Processing Record 48 of Set 2 | khatanga
# Processing Record 49 of Set 2 | padang
# Processing Record 50 of Set 2 | lujiang
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | urengoy
# Processing Record 3 of Set 3 | sidi bu zayd
# City not found. Skipping...
# Processing Record 4 of Set 3 | sao filipe
# Processing Record 5 of Set 3 | skarzysko-kamienna
# Processing Record 6 of Set 3 | seoul
# Processing Record 7 of Set 3 | ocsod
# Processing Record 8 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 3 | papetoai
# Processing Record 10 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 3 | butaritari
# Processing Record 12 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | klaksvik
# Processing Record 15 of Set 3 | ketchikan
# Processing Record 16 of Set 3 | balotra
# Processing Record 17 of Set 3 | punta cardon
# Processing Record 18 of Set 3 | hithadhoo
# Processing Record 19 of Set 3 | esperance
# Processing Record 20 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 3 | kloulklubed
# Processing Record 22 of Set 3 | ponta do sol
# Processing Record 23 of Set 3 | biak
# Processing Record 24 of Set 3 | pingxiang
# Processing Record 25 of Set 3 | rayagada
# Processing Record 26 of Set 3 | namibe
# Processing Record 27 of Set 3 | dikson
# Processing Record 28 of Set 3 | emirdag
# Processing Record 29 of Set 3 | kyzyl-suu
# Processing Record 30 of Set 3 | sur
# Processing Record 31 of Set 3 | itarema
# Processing Record 32 of Set 3 | ginir
# Processing Record 33 of Set 3 | balikpapan
# Processing Record 34 of Set 3 | saldanha
# Processing Record 35 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 3 | bluff
# Processing Record 37 of Set 3 | presidencia roque saenz pena
# Processing Record 38 of Set 3 | castro
# Processing Record 39 of Set 3 | mount isa
# Processing Record 40 of Set 3 | cervo
# Processing Record 41 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 3 | east london
# Processing Record 43 of Set 3 | nanortalik
# Processing Record 44 of Set 3 | norilsk
# Processing Record 45 of Set 3 | faanui
# Processing Record 46 of Set 3 | chuy
# Processing Record 47 of Set 3 | sovetskiy
# Processing Record 48 of Set 3 | lubango
# Processing Record 49 of Set 3 | levelland
# Processing Record 50 of Set 3 | tiksi
# Processing Record 1 of Set 4 | xixiang
# Processing Record 2 of Set 4 | georgetown
# Processing Record 3 of Set 4 | mataram
# Processing Record 4 of Set 4 | labuan
# Processing Record 5 of Set 4 | saint-augustin
# Processing Record 6 of Set 4 | chernyshevskiy
# Processing Record 7 of Set 4 | ixtapa
# Processing Record 8 of Set 4 | talara
# Processing Record 9 of Set 4 | sao jose da coroa grande
# Processing Record 10 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 4 | shchigry
# Processing Record 12 of Set 4 | hamilton
# Processing Record 13 of Set 4 | constitucion
# Processing Record 14 of Set 4 | rio grande
# Processing Record 15 of Set 4 | akyab
# Processing Record 16 of Set 4 | cherskiy
# Processing Record 17 of Set 4 | warri
# Processing Record 18 of Set 4 | thinadhoo
# Processing Record 19 of Set 4 | lancaster
# Processing Record 20 of Set 4 | zyryanka
# Processing Record 21 of Set 4 | santa rosalia
# Processing Record 22 of Set 4 | chapada dos guimaraes
# Processing Record 23 of Set 4 | aitape
# Processing Record 24 of Set 4 | quelimane
# Processing Record 25 of Set 4 | tocopilla
# Processing Record 26 of Set 4 | codrington
# Processing Record 27 of Set 4 | kieta
# Processing Record 28 of Set 4 | arona
# Processing Record 29 of Set 4 | handlova
# Processing Record 30 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 4 | puerto ayora
# Processing Record 32 of Set 4 | san luis
# Processing Record 33 of Set 4 | nome
# Processing Record 34 of Set 4 | emerald
# Processing Record 35 of Set 4 | tuatapere
# Processing Record 36 of Set 4 | ozinki
# Processing Record 37 of Set 4 | uchaly
# Processing Record 38 of Set 4 | ankazoabo
# Processing Record 39 of Set 4 | norashen
# Processing Record 40 of Set 4 | vanimo
# Processing Record 41 of Set 4 | olafsvik
# Processing Record 42 of Set 4 | teguldet
# Processing Record 43 of Set 4 | kamaishi
# Processing Record 44 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 4 | bitung
# Processing Record 46 of Set 4 | airai
# Processing Record 47 of Set 4 | tual
# Processing Record 48 of Set 4 | narasannapeta
# Processing Record 49 of Set 4 | nikolskoye
# Processing Record 50 of Set 4 | balkhash
# Processing Record 1 of Set 5 | les cayes
# Processing Record 2 of Set 5 | chimbote
# Processing Record 3 of Set 5 | kampong cham
# Processing Record 4 of Set 5 | jumla
# Processing Record 5 of Set 5 | venice
# Processing Record 6 of Set 5 | chastoozerye
# City not found. Skipping...
# Processing Record 7 of Set 5 | lluta
# Processing Record 8 of Set 5 | dover
# Processing Record 9 of Set 5 | anadyr
# Processing Record 10 of Set 5 | wamba
# Processing Record 11 of Set 5 | victoria
# Processing Record 12 of Set 5 | eyl
# Processing Record 13 of Set 5 | tugulym
# Processing Record 14 of Set 5 | thano bula khan
# City not found. Skipping...
# Processing Record 15 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 5 | khartoum
# Processing Record 17 of Set 5 | pauini
# Processing Record 18 of Set 5 | kamennomostskiy
# Processing Record 19 of Set 5 | coihaique
# Processing Record 20 of Set 5 | vung tau
# Processing Record 21 of Set 5 | oktyabrskiy
# Processing Record 22 of Set 5 | ongandjera
# Processing Record 23 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 5 | matao
# Processing Record 25 of Set 5 | svetlogorsk
# Processing Record 26 of Set 5 | grand gaube
# Processing Record 27 of Set 5 | waingapu
# Processing Record 28 of Set 5 | bar-le-duc
# Processing Record 29 of Set 5 | bambous virieux
# Processing Record 30 of Set 5 | bonavista
# Processing Record 31 of Set 5 | whitianga
# Processing Record 32 of Set 5 | qaanaaq
# Processing Record 33 of Set 5 | konigs wusterhausen
# Processing Record 34 of Set 5 | kovdor
# Processing Record 35 of Set 5 | nogent-le-rotrou
# Processing Record 36 of Set 5 | lorengau
# Processing Record 37 of Set 5 | prince rupert
# Processing Record 38 of Set 5 | provideniya
# Processing Record 39 of Set 5 | north platte
# Processing Record 40 of Set 5 | marawi
# Processing Record 41 of Set 5 | lokken verk
# City not found. Skipping...
# Processing Record 42 of Set 5 | sawtell
# Processing Record 43 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 5 | atasu
# Processing Record 45 of Set 5 | lompoc
# Processing Record 46 of Set 5 | ambilobe
# Processing Record 47 of Set 5 | xaltianguis
# Processing Record 48 of Set 5 | bilma
# Processing Record 49 of Set 5 | saint george
# Processing Record 50 of Set 5 | fort abbas
# Processing Record 1 of Set 6 | suriapet
# Processing Record 2 of Set 6 | cradock
# Processing Record 3 of Set 6 | bakel
# Processing Record 4 of Set 6 | vila franca do campo
# Processing Record 5 of Set 6 | torbay
# Processing Record 6 of Set 6 | bhadra
# Processing Record 7 of Set 6 | ugoofaaru
# Processing Record 8 of Set 6 | boa vista
# Processing Record 9 of Set 6 | bathsheba
# Processing Record 10 of Set 6 | ondjiva
# Processing Record 11 of Set 6 | nangka
# Processing Record 12 of Set 6 | leningradskiy
# Processing Record 13 of Set 6 | severo-kurilsk
# Processing Record 14 of Set 6 | muncar
# Processing Record 15 of Set 6 | ancud
# Processing Record 16 of Set 6 | kaeo
# Processing Record 17 of Set 6 | cockburn town
# Processing Record 18 of Set 6 | ngorongoro
# Processing Record 19 of Set 6 | port blair
# Processing Record 20 of Set 6 | mar del plata
# Processing Record 21 of Set 6 | tarakan
# Processing Record 22 of Set 6 | shenjiamen
# Processing Record 23 of Set 6 | chaiya
# Processing Record 24 of Set 6 | berlevag
# Processing Record 25 of Set 6 | pisco
# Processing Record 26 of Set 6 | musoma
# Processing Record 27 of Set 6 | golkoy
# Processing Record 28 of Set 6 | uarini
# Processing Record 29 of Set 6 | mahon
# Processing Record 30 of Set 6 | shache
# Processing Record 31 of Set 6 | nizwa
# Processing Record 32 of Set 6 | podgorica
# Processing Record 33 of Set 6 | barra do garcas
# Processing Record 34 of Set 6 | portland
# Processing Record 35 of Set 6 | yeppoon
# Processing Record 36 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 6 | bokoro
# Processing Record 38 of Set 6 | the valley
# Processing Record 39 of Set 6 | moose factory
# Processing Record 40 of Set 6 | guerrero negro
# Processing Record 41 of Set 6 | mnogovershinnyy
# Processing Record 42 of Set 6 | conde
# Processing Record 43 of Set 6 | mareeba
# Processing Record 44 of Set 6 | quatre cocos
# Processing Record 45 of Set 6 | baoning
# Processing Record 46 of Set 6 | tuktoyaktuk
# Processing Record 47 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 6 | altamont
# Processing Record 49 of Set 6 | lavrentiya
# Processing Record 50 of Set 6 | tongchuan
# Processing Record 1 of Set 7 | patiya
# Processing Record 2 of Set 7 | iskateley
# Processing Record 3 of Set 7 | krasnyy kut
# Processing Record 4 of Set 7 | georgiyevskoye
# Processing Record 5 of Set 7 | wilmington
# Processing Record 6 of Set 7 | kaseda
# Processing Record 7 of Set 7 | hobyo
# Processing Record 8 of Set 7 | cheremkhovo
# Processing Record 9 of Set 7 | nevelsk
# Processing Record 10 of Set 7 | katra
# Processing Record 11 of Set 7 | swinoujscie
# Processing Record 12 of Set 7 | batemans bay
# Processing Record 13 of Set 7 | aklavik
# Processing Record 14 of Set 7 | lata
# Processing Record 15 of Set 7 | burica
# City not found. Skipping...
# Processing Record 16 of Set 7 | fomboni
# Processing Record 17 of Set 7 | salalah
# Processing Record 18 of Set 7 | quesnel
# Processing Record 19 of Set 7 | bhag
# Processing Record 20 of Set 7 | moranbah
# Processing Record 21 of Set 7 | vidalia
# Processing Record 22 of Set 7 | narsaq
# Processing Record 23 of Set 7 | ulaangom
# Processing Record 24 of Set 7 | fuzhou
# Processing Record 25 of Set 7 | sioux lookout
# Processing Record 26 of Set 7 | alamosa
# Processing Record 27 of Set 7 | lusambo
# Processing Record 28 of Set 7 | kutahya
# Processing Record 29 of Set 7 | sorochinsk
# Processing Record 30 of Set 7 | kimbe
# Processing Record 31 of Set 7 | necochea
# Processing Record 32 of Set 7 | varhaug
# Processing Record 33 of Set 7 | yulara
# Processing Record 34 of Set 7 | carai
# Processing Record 35 of Set 7 | dongying
# Processing Record 36 of Set 7 | bengkulu
# Processing Record 37 of Set 7 | zlobin
# Processing Record 38 of Set 7 | mwinilunga
# Processing Record 39 of Set 7 | puerto escondido
# Processing Record 40 of Set 7 | yumen
# Processing Record 41 of Set 7 | kalianget
# Processing Record 42 of Set 7 | ikungi
# Processing Record 43 of Set 7 | husavik
# Processing Record 44 of Set 7 | anshun
# Processing Record 45 of Set 7 | santiago
# Processing Record 46 of Set 7 | camacha
# Processing Record 47 of Set 7 | marzuq
# Processing Record 48 of Set 7 | matagami
# Processing Record 49 of Set 7 | sibolga
# Processing Record 50 of Set 7 | huarmey
# Processing Record 1 of Set 8 | onokhino
# Processing Record 2 of Set 8 | bichura
# Processing Record 3 of Set 8 | port lincoln
# Processing Record 4 of Set 8 | okhotsk
# Processing Record 5 of Set 8 | grahamstown
# Processing Record 6 of Set 8 | celendin
# Processing Record 7 of Set 8 | fort nelson
# Processing Record 8 of Set 8 | svetlaya
# Processing Record 9 of Set 8 | saint-georges
# Processing Record 10 of Set 8 | adre
# Processing Record 11 of Set 8 | igbaras
# Processing Record 12 of Set 8 | gravdal
# Processing Record 13 of Set 8 | pontes e lacerda
# Processing Record 14 of Set 8 | arraial do cabo
# Processing Record 15 of Set 8 | khash
# Processing Record 16 of Set 8 | yagodnoye
# Processing Record 17 of Set 8 | nuuk
# Processing Record 18 of Set 8 | qui nhon
# Processing Record 19 of Set 8 | korla
# Processing Record 20 of Set 8 | peace river
# Processing Record 21 of Set 8 | coreau
# Processing Record 22 of Set 8 | goderich
# Processing Record 23 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 8 | harper
# Processing Record 25 of Set 8 | san fernando
# Processing Record 26 of Set 8 | cam ranh
# Processing Record 27 of Set 8 | college
# Processing Record 28 of Set 8 | canico
# Processing Record 29 of Set 8 | baherden
# Processing Record 30 of Set 8 | lixourion
# Processing Record 31 of Set 8 | pundaguitan
# Processing Record 32 of Set 8 | beyneu
# Processing Record 33 of Set 8 | koumac
# Processing Record 34 of Set 8 | lukovetskiy
# Processing Record 35 of Set 8 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 36 of Set 8 | eureka
# Processing Record 37 of Set 8 | nijmegen
# Processing Record 38 of Set 8 | bontang
# Processing Record 39 of Set 8 | cidreira
# Processing Record 40 of Set 8 | clyde river
# Processing Record 41 of Set 8 | ionia
# Processing Record 42 of Set 8 | caravelas
# Processing Record 43 of Set 8 | yenagoa
# Processing Record 44 of Set 8 | chapais
# Processing Record 45 of Set 8 | katobu
# Processing Record 46 of Set 8 | sorong
# Processing Record 47 of Set 8 | alice
# Processing Record 48 of Set 8 | coruche
# Processing Record 49 of Set 8 | ilulissat
# Processing Record 50 of Set 8 | half moon bay
# Processing Record 1 of Set 9 | topolobampo
# Processing Record 2 of Set 9 | garowe
# Processing Record 3 of Set 9 | great yarmouth
# Processing Record 4 of Set 9 | abiy adi
# City not found. Skipping...
# Processing Record 5 of Set 9 | port hardy
# Processing Record 6 of Set 9 | piopio
# Processing Record 7 of Set 9 | ladario
# Processing Record 8 of Set 9 | westerly
# Processing Record 9 of Set 9 | dingle
# Processing Record 10 of Set 9 | almenara
# Processing Record 11 of Set 9 | smidovich
# Processing Record 12 of Set 9 | kamalasai
# Processing Record 13 of Set 9 | saint-pierre
# Processing Record 14 of Set 9 | namatanai
# Processing Record 15 of Set 9 | kondagaon
# Processing Record 16 of Set 9 | tsiroanomandidy
# Processing Record 17 of Set 9 | isiro
# Processing Record 18 of Set 9 | furstenwalde
# Processing Record 19 of Set 9 | rocha
# Processing Record 20 of Set 9 | alofi
# Processing Record 21 of Set 9 | edson
# Processing Record 22 of Set 9 | umm lajj
# Processing Record 23 of Set 9 | dalian
# Processing Record 24 of Set 9 | ankara
# Processing Record 25 of Set 9 | mora
# Processing Record 26 of Set 9 | hofn
# Processing Record 27 of Set 9 | los andes
# Processing Record 28 of Set 9 | bongandanga
# Processing Record 29 of Set 9 | aksarka
# Processing Record 30 of Set 9 | odienne
# Processing Record 31 of Set 9 | porto seguro
# Processing Record 32 of Set 9 | richards bay
# Processing Record 33 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 34 of Set 9 | tilichiki
# Processing Record 35 of Set 9 | qasigiannguit
# Processing Record 36 of Set 9 | singkang
# Processing Record 37 of Set 9 | juneau
# Processing Record 38 of Set 9 | taoudenni
# Processing Record 39 of Set 9 | ewa beach
# Processing Record 40 of Set 9 | vitimskiy
# City not found. Skipping...
# Processing Record 41 of Set 9 | ola
# Processing Record 42 of Set 9 | juigalpa
# Processing Record 43 of Set 9 | middelburg
# Processing Record 44 of Set 9 | verkhnevilyuysk
# Processing Record 45 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 46 of Set 9 | trincomalee
# Processing Record 47 of Set 9 | pandamatenga
# Processing Record 48 of Set 9 | gonzalez
# Processing Record 49 of Set 9 | florianopolis
# Processing Record 50 of Set 9 | malanje
# Processing Record 1 of Set 10 | sao joao do piaui
# Processing Record 2 of Set 10 | puerto cabezas
# Processing Record 3 of Set 10 | burns lake
# Processing Record 4 of Set 10 | playa vicente
# Processing Record 5 of Set 10 | aykhal
# Processing Record 6 of Set 10 | carballo
# Processing Record 7 of Set 10 | mugumu
# Processing Record 8 of Set 10 | takoradi
# Processing Record 9 of Set 10 | kodiak
# Processing Record 10 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 11 of Set 10 | ballina
# Processing Record 12 of Set 10 | makamba
# Processing Record 13 of Set 10 | superior
# Processing Record 14 of Set 10 | san patricio
# Processing Record 15 of Set 10 | comodoro rivadavia
# Processing Record 16 of Set 10 | porgera
# Processing Record 17 of Set 10 | caucaia
# Processing Record 18 of Set 10 | kruisfontein
# Processing Record 19 of Set 10 | san ignacio
# Processing Record 20 of Set 10 | colares
# Processing Record 21 of Set 10 | road town
# Processing Record 22 of Set 10 | bollnas
# Processing Record 23 of Set 10 | jalu
# Processing Record 24 of Set 10 | priargunsk
# Processing Record 25 of Set 10 | antofagasta
# Processing Record 26 of Set 10 | deputatskiy
# Processing Record 27 of Set 10 | cape canaveral
# Processing Record 28 of Set 10 | baruun-urt
# Processing Record 29 of Set 10 | karratha
# Processing Record 30 of Set 10 | dilla
# Processing Record 31 of Set 10 | mehamn
# Processing Record 32 of Set 10 | kincardine
# Processing Record 33 of Set 10 | phra phutthabat
# Processing Record 34 of Set 10 | udachnyy
# Processing Record 35 of Set 10 | bien hoa
# Processing Record 36 of Set 10 | henderson
# Processing Record 37 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 38 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 39 of Set 10 | banda aceh
# Processing Record 40 of Set 10 | isla mujeres
# Processing Record 41 of Set 10 | hirado
# Processing Record 42 of Set 10 | sobolevo
# Processing Record 43 of Set 10 | ostrovnoy
# Processing Record 44 of Set 10 | yar-sale
# Processing Record 45 of Set 10 | paka
# Processing Record 46 of Set 10 | cubuk
# Processing Record 47 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 10 | angoche
# Processing Record 49 of Set 10 | riyadh
# Processing Record 50 of Set 10 | kota
# Processing Record 1 of Set 11 | sao felix do xingu
# Processing Record 2 of Set 11 | kudahuvadhoo
# Processing Record 3 of Set 11 | knokke-heist
# Processing Record 4 of Set 11 | tibu
# Processing Record 5 of Set 11 | leshukonskoye
# Processing Record 6 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 11 | flin flon
# Processing Record 8 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 11 | manokwari
# Processing Record 10 of Set 11 | katsuura
# Processing Record 11 of Set 11 | miles city
# Processing Record 12 of Set 11 | dustlik
# Processing Record 13 of Set 11 | norman wells
# Processing Record 14 of Set 11 | ceres
# Processing Record 15 of Set 11 | kapuskasing
# Processing Record 16 of Set 11 | general roca
# Processing Record 17 of Set 11 | cayenne
# Processing Record 18 of Set 11 | newcastle
# Processing Record 19 of Set 11 | hegang
# Processing Record 20 of Set 11 | alice springs
# Processing Record 21 of Set 11 | khudumelapye
# Processing Record 22 of Set 11 | lere
# Processing Record 23 of Set 11 | xingcheng
# Processing Record 24 of Set 11 | ishigaki
# Processing Record 25 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 26 of Set 11 | cuamba
# Processing Record 27 of Set 11 | isangel
# Processing Record 28 of Set 11 | acarau
# Processing Record 29 of Set 11 | acajutla
# Processing Record 30 of Set 11 | kaili
# Processing Record 31 of Set 11 | tongliao
# Processing Record 32 of Set 11 | dubbo
# Processing Record 33 of Set 11 | norden
# Processing Record 34 of Set 11 | salisbury
# Processing Record 35 of Set 11 | dogondoutchi
# Processing Record 36 of Set 11 | tynda
# Processing Record 37 of Set 11 | kapit
# Processing Record 38 of Set 11 | vila velha
# Processing Record 39 of Set 11 | lensk
# Processing Record 40 of Set 11 | lasa
# Processing Record 41 of Set 11 | meulaboh
# Processing Record 42 of Set 11 | hammerfest
# Processing Record 43 of Set 11 | zheleznodorozhnyy
# Processing Record 44 of Set 11 | marrakesh
# Processing Record 45 of Set 11 | kirakira
# Processing Record 46 of Set 11 | port hueneme
# Processing Record 47 of Set 11 | mizdah
# Processing Record 48 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 11 | leh
# Processing Record 50 of Set 11 | alyangula
# Processing Record 1 of Set 12 | palmer
# Processing Record 2 of Set 12 | maralal
# Processing Record 3 of Set 12 | sukumo
# Processing Record 4 of Set 12 | champerico
# Processing Record 5 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 12 | glamoc
# Processing Record 7 of Set 12 | daura
# Processing Record 8 of Set 12 | bay roberts
# Processing Record 9 of Set 12 | kerouane
# Processing Record 10 of Set 12 | belyy yar
# Processing Record 11 of Set 12 | teya
# Processing Record 12 of Set 12 | tigre
# Processing Record 13 of Set 12 | berea
# Processing Record 14 of Set 12 | los llanos de aridane
# Processing Record 15 of Set 12 | jinxiang
# Processing Record 16 of Set 12 | morondava
# Processing Record 17 of Set 12 | luderitz
# Processing Record 18 of Set 12 | poso
# Processing Record 19 of Set 12 | la palma
# Processing Record 20 of Set 12 | dzhebariki-khaya
# Processing Record 21 of Set 12 | payo
# Processing Record 22 of Set 12 | la ronge
# Processing Record 23 of Set 12 | kjollefjord
# Processing Record 24 of Set 12 | makaleng
# Processing Record 25 of Set 12 | manta
# Processing Record 26 of Set 12 | maneadero
# Processing Record 27 of Set 12 | marsh harbour
# Processing Record 28 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 12 | pochutla
# Processing Record 31 of Set 12 | riverton
# Processing Record 32 of Set 12 | aden
# Processing Record 33 of Set 12 | sapa
# Processing Record 34 of Set 12 | mackay
# Processing Record 35 of Set 12 | kingisepp
# Processing Record 36 of Set 12 | hohhot
# Processing Record 37 of Set 12 | atar
# Processing Record 38 of Set 12 | xining
# Processing Record 39 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 12 | coahuayana
# Processing Record 41 of Set 12 | xuddur
# Processing Record 42 of Set 12 | trelew
# Processing Record 43 of Set 12 | fortuna
# Processing Record 44 of Set 12 | ust-uda
# Processing Record 45 of Set 12 | komsomolskiy
# Processing Record 46 of Set 12 | raudeberg
# Processing Record 47 of Set 12 | hrebinka
# Processing Record 48 of Set 12 | sinop
# Processing Record 49 of Set 12 | camopi
# Processing Record 50 of Set 12 | ayr
# Processing Record 1 of Set 13 | dunmore town
# Processing Record 2 of Set 13 | litovko
# Processing Record 3 of Set 13 | tomatlan
# Processing Record 4 of Set 13 | embonas
# Processing Record 5 of Set 13 | liverpool
# Processing Record 6 of Set 13 | arlit
# Processing Record 7 of Set 13 | flinders
# Processing Record 8 of Set 13 | luena
# Processing Record 9 of Set 13 | mudanya
# Processing Record 10 of Set 13 | pingdu
# Processing Record 11 of Set 13 | saint-denis
# Processing Record 12 of Set 13 | hambantota
# Processing Record 13 of Set 13 | beringovskiy
# Processing Record 14 of Set 13 | takaka
# Processing Record 15 of Set 13 | asau
# Processing Record 16 of Set 13 | capao da canoa
# Processing Record 17 of Set 13 | homer
# Processing Record 18 of Set 13 | bandipur
# Processing Record 19 of Set 13 | zhicheng
# Processing Record 20 of Set 13 | gidam
# Processing Record 21 of Set 13 | uberaba
# Processing Record 22 of Set 13 | khasan
# Processing Record 23 of Set 13 | bac lieu
# Processing Record 24 of Set 13 | gizo
# Processing Record 25 of Set 13 | alcaniz
# Processing Record 26 of Set 13 | kavaratti
# Processing Record 27 of Set 13 | khani
# Processing Record 28 of Set 13 | khipro
# Processing Record 29 of Set 13 | sitka
# Processing Record 30 of Set 13 | tagusao
# Processing Record 31 of Set 13 | cabo san lucas
# Processing Record 32 of Set 13 | vila
# Processing Record 33 of Set 13 | volosovo
# Processing Record 34 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 35 of Set 13 | tamandare
# Processing Record 36 of Set 13 | avera
# Processing Record 37 of Set 13 | mpongwe
# Processing Record 38 of Set 13 | marsa matruh
# Processing Record 39 of Set 13 | walvis bay
# Processing Record 40 of Set 13 | vestmannaeyjar
# Processing Record 41 of Set 13 | manggar
# Processing Record 42 of Set 13 | srednekolymsk
# Processing Record 43 of Set 13 | troitsko-pechorsk
# Processing Record 44 of Set 13 | hami
# Processing Record 45 of Set 13 | bubaque
# Processing Record 46 of Set 13 | bantry
# Processing Record 47 of Set 13 | san policarpo
# Processing Record 48 of Set 13 | pagudpud
# Processing Record 49 of Set 13 | hirekerur
# Processing Record 50 of Set 13 | sisimiut
# Processing Record 1 of Set 14 | la paz
# Processing Record 2 of Set 14 | novobirilyussy
# Processing Record 3 of Set 14 | ust-nera
# Processing Record 4 of Set 14 | dolovo
# Processing Record 5 of Set 14 | skaudvile
# Processing Record 6 of Set 14 | tarhunah
# City not found. Skipping...
# Processing Record 7 of Set 14 | dancheng
# Processing Record 8 of Set 14 | sivas
# Processing Record 9 of Set 14 | salaga
# Processing Record 10 of Set 14 | stara synyava
# Processing Record 11 of Set 14 | caluquembe
# Processing Record 12 of Set 14 | sao joao da barra
# Processing Record 13 of Set 14 | broome
# Processing Record 14 of Set 14 | ust-shonosha
# Processing Record 15 of Set 14 | adrar
# Processing Record 16 of Set 14 | ndende
# Processing Record 17 of Set 14 | erzin
# Processing Record 18 of Set 14 | morgan city
# Processing Record 19 of Set 14 | tura
# Processing Record 20 of Set 14 | alindao
# Processing Record 21 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 14 | cabedelo
# Processing Record 23 of Set 14 | shimoda
# Processing Record 24 of Set 14 | nesbyen
# Processing Record 25 of Set 14 | pampa
# Processing Record 26 of Set 14 | ayan
# Processing Record 27 of Set 14 | merauke
# Processing Record 28 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 14 | bansi
# Processing Record 30 of Set 14 | sergeyevka
# Processing Record 31 of Set 14 | bodden town
# Processing Record 32 of Set 14 | mana
# Processing Record 33 of Set 14 | buraydah
# Processing Record 34 of Set 14 | tambovka
# Processing Record 35 of Set 14 | waipawa
# Processing Record 36 of Set 14 | monroe
# Processing Record 37 of Set 14 | praia da vitoria
# Processing Record 38 of Set 14 | pak phanang
# Processing Record 39 of Set 14 | port macquarie
# Processing Record 40 of Set 14 | naron
# Processing Record 41 of Set 14 | sinnamary
# Processing Record 42 of Set 14 | robertson
# Processing Record 43 of Set 14 | badvel
# Processing Record 44 of Set 14 | oistins
# Processing Record 45 of Set 14 | harpalpur
# Processing Record 46 of Set 14 | sambava
# Processing Record 47 of Set 14 | mgandu
# Processing Record 48 of Set 14 | port-cartier
# Processing Record 49 of Set 14 | podosinovets
# Processing Record 50 of Set 14 | sechura
# Processing Record 1 of Set 15 | kribi
# Processing Record 2 of Set 15 | varkkallai
# Processing Record 3 of Set 15 | san juan
# Processing Record 4 of Set 15 | vostok
# Processing Record 5 of Set 15 | aktau
# Processing Record 6 of Set 15 | tommot
# Processing Record 7 of Set 15 | honiara
# Processing Record 8 of Set 15 | kampot
# Processing Record 9 of Set 15 | laguna
# Processing Record 10 of Set 15 | paucartambo
# City not found. Skipping...
# Processing Record 11 of Set 15 | krasnyy oktyabr
# Processing Record 12 of Set 15 | uyuni
# Processing Record 13 of Set 15 | shingu
# Processing Record 14 of Set 15 | barinas
# Processing Record 15 of Set 15 | mayumba
# Processing Record 16 of Set 15 | bilibino
# Processing Record 17 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 15 | jinchang
# Processing Record 19 of Set 15 | hun
# Processing Record 20 of Set 15 | buala
# Processing Record 21 of Set 15 | luganville
# Processing Record 22 of Set 15 | puerto madryn
# Processing Record 23 of Set 15 | fowa
# Processing Record 24 of Set 15 | la seyne-sur-mer
# Processing Record 25 of Set 15 | usinsk
# Processing Record 26 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 15 | kamina
# Processing Record 28 of Set 15 | pilar
# Processing Record 29 of Set 15 | pinkafeld
# Processing Record 30 of Set 15 | liku
# Processing Record 31 of Set 15 | ust-ilimsk
# Processing Record 32 of Set 15 | tautira
# Processing Record 33 of Set 15 | dryden
# Processing Record 34 of Set 15 | ternate
# Processing Record 35 of Set 15 | arrifes
# Processing Record 36 of Set 15 | nova olimpia
# Processing Record 37 of Set 15 | dien bien
# City not found. Skipping...
# Processing Record 38 of Set 15 | lugovoy
# Processing Record 39 of Set 15 | diu
# Processing Record 40 of Set 15 | evinayong
# Processing Record 41 of Set 15 | skagen
# Processing Record 42 of Set 15 | wiarton
# Processing Record 43 of Set 15 | laje
# Processing Record 44 of Set 15 | rawson
# Processing Record 45 of Set 15 | benghazi
# Processing Record 46 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 15 | agadir
# Processing Record 48 of Set 15 | burnie
# Processing Record 49 of Set 15 | jiuquan
# Processing Record 50 of Set 15 | imbituba
# Processing Record 1 of Set 16 | cotonou
# Processing Record 2 of Set 16 | karasjok
# Processing Record 3 of Set 16 | envira
# Processing Record 4 of Set 16 | kajaani
# Processing Record 5 of Set 16 | talcahuano
# Processing Record 6 of Set 16 | awbari
# Processing Record 7 of Set 16 | pangnirtung
# Processing Record 8 of Set 16 | puerto del rosario
# Processing Record 9 of Set 16 | xuanhua
# Processing Record 10 of Set 16 | trairi
# Processing Record 11 of Set 16 | vardo
# Processing Record 12 of Set 16 | rurrenabaque
# Processing Record 13 of Set 16 | spirovo
# Processing Record 14 of Set 16 | chicama
# Processing Record 15 of Set 16 | puno
# Processing Record 16 of Set 16 | tiruvottiyur
# City not found. Skipping...
# Processing Record 17 of Set 16 | churapcha
# Processing Record 18 of Set 16 | vao
# Processing Record 19 of Set 16 | touros
# Processing Record 20 of Set 16 | tarko-sale
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Lagoa  39.05  -27.98     64.63        80          90       21.94
# 1    Wageningen  51.97    5.67     64.00        93          75       11.41
# 2       Ushuaia -54.80  -68.30     59.00        54          75        4.70
# 3        Dennis  41.74  -70.19     57.99        76          75        6.93
# 4        Barrow  71.29 -156.79     26.60        79          90       12.75
# ..          ...    ...     ...       ...       ...         ...         ...
# 712        Puno -15.83  -70.03     64.40        17           0        5.82
# 713   Churapcha  62.00  132.43    -17.68        88          21        2.04
# 714         Vao -22.67  167.48     74.05        85          55       18.72
# 715      Touros  -5.20  -35.46     86.00        62          40       16.11
# 716  Tarko-Sale  64.92   77.78     30.13        98          95       18.41
#
#     Country Current Description
# 0        PT          light rain
# 1        NL       broken clouds
# 2        AR          light rain
# 3        US       broken clouds
# 4        US                snow
# ..      ...                 ...
# 712      PE           clear sky
# 713      RU          few clouds
# 714      NC       broken clouds
# 715      BR    scattered clouds
# 716      RU     overcast clouds
#
# [717 rows x 9 columns]

# %%
# Reorder Columns
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

# %%
# Reorder DataFrame Columns
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Lagoa      PT  39.05  -27.98     64.63        80          90
# 1     Wageningen      NL  51.97    5.67     64.00        93          75
# 2        Ushuaia      AR -54.80  -68.30     59.00        54          75
# 3         Dennis      US  41.74  -70.19     57.99        76          75
# 4         Barrow      US  71.29 -156.79     26.60        79          90
# 5           Jadu      LY  31.95   12.03     61.79        71          57
# 6  Saint Anthony      US  45.02  -93.22     34.00        65           1
# 7          Kutum      SD  14.20   24.67     80.11        21          53
# 8      Mahebourg      MU -20.41   57.70     69.80        68          40
# 9        Rikitea      PF -23.12 -134.97     74.93        84          42
#
#    Wind Speed Current Description
# 0       21.94          light rain
# 1       11.41       broken clouds
# 2        4.70          light rain
# 3        6.93       broken clouds
# 4       12.75                snow
# 5        6.93       broken clouds
# 6       17.22           clear sky
# 7        9.44       broken clouds
# 8        4.70    scattered clouds
# 9       15.64          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
